# %%
import pandas as pd

#pd.read_csv()

data = pd.Series(["Январь", "Февраль", "Март", "Апрель"])
data1 = pd.Series(["Январь", "Февраль", "Март", "Апрель"],
             index = ['Первый', "Второй", "Третий", "Четвёртый"])
display(data)
display(data1)
# Out:
# 0     Январь
# 1    Февраль
# 2       Март
# 3     Апрель
# dtype: object
# Первый        Январь
# Второй       Февраль
# Третий          Март
# Четвёртый     Апрель
# dtype: object

# %%
print(data1.iloc[0],[2])
print(data1.iloc[[1,2]])
# Out:
# Январь [2]
# Второй    Февраль
# Третий       Март
# dtype: object

# %%
df = pd.DataFrame({'col1': [1,2,3], 'col2':[1,4,3]},
                 index = range(1, 4))
display(df)
# Out:
#    col1  col2
# 1     1     1
# 2     2     4
# 3     3     3

# %%
data = pd.Series(list(range(10, 1001)))
print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
print(data.loc[990])
# Out:
# -70
# 1000

# %%
import pandas as pd

data = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
display(data.head(2))
display(data.tail(2))
display(data.info())
# Out:
#    Unnamed: 0               Name  Age Nationality          Club      Value  \
# 0           0           L. Messi   31   Argentina  FC Barcelona  110500000
# 1           1  Cristiano Ronaldo   33    Portugal      Juventus   77000000
#
#      Wage Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0  565000       RF        84         95  ...         75         96       33
# 1  405000       ST        84         94  ...         85         95       28
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
# 1              31             23         7          11         15
#
#    GKPositioning  GKReflexes
# 0             14           8
# 1             14          11
#
# [2 rows x 42 columns]
#        Unnamed: 0            Name  Age Nationality             Club  Value  \
# 12895       13124  D. Walker-Rice   17     England  Tranmere Rovers  60000
# ...

# %%
import pandas as pd

data = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
display(data.describe(include = ['object']))
display(data.describe())

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data.describe())
display(data.Age.mean()) #max, min, count, std, sum
# Out:
#                 Name Nationality              Club Position
# count          12897       12897             12897    12897
# unique         12326         156               650       27
# top     J. Rodríguez     England  V-Varen Nagasaki       GK
# freq               9        1368                30     1641
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# ...

# %%
import pandas as pd
football = pd.read_csv('http://ai-academy.ru/upload/csv/football_mini.csv')
age = int(round(football.Age.mean(),0))
n = football.describe(include = ['object']).Nationality.top
print(age, n)
# Out:
# 28 Spain

# %%
import pandas as pd
football = pd.read_csv('http://ai-academy.ru/upload/csv/football_mini.csv')
display(football[(football.Age < football.Age.mean())&
                (football.Club == 'FC Barcelona')])
print(football[(football.Age < football.Age.mean())&
                (football.Club == 'FC Barcelona')].Wage.mean())
# Out:
#     Unnamed: 0           Name  Age Nationality          Club     Value  \
# 18          18  M. ter Stegen   26     Germany  FC Barcelona  58000000
# 32          32       Coutinho   26      Brazil  FC Barcelona  69500000
# 42          42      S. Umtiti   24      France  FC Barcelona  57000000
#
#       Wage Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 18  240000       GK        15         14  ...         25         69       25
# 32  340000       LW        79         79  ...         70         85       55
# 42  205000       CB        69         51  ...         61         82       90
#
#     StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 18              13             10        87          85         88
# 32              54             47        12           7          9
# 42              89             86        15          10         14
#
#     GKPositioning  GKReflexes
# 18             85          90
# 32             14           6
# ...

# %%
import pandas as pd
data = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
print(round(data[(data.Wage < data.Wage.mean())].SprintSpeed.mean(),2))
print(data[(data.Composure > 0.9*data.Composure.max())&
           (data.Reactions > 0.9*data.Reactions.max())].Age.min())
print(data[(data.Value > data.Value.mean())].describe(include = ['object']).Nationality.top)
# Out:
# 62.41
# 24
# Spain

# %%
import pandas as pd
data = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
A = data[data.Nationality == 'France']
B = data[data.Nationality == 'Spain']
C = data[data.Nationality == 'England']
table = pd.DataFrame({'mean Age': [A.Age.mean(), B.Age.mean(),C.Age.mean()]}, 
                      index = ['France','Spain', 'England'])
display(table)

#считает количество разных значений национальностей
s = data.Nationality.value_counts()
print(s.index[0], len(s.index), s['Russia'] , '\n', s.loc[s>400] )

#считает в процентах  normalize=True
si = data['Nationality'].value_counts(normalize=True)
display(si)
# Out:
#           mean Age
# France   24.175896
# Spain    24.965723
# England  23.805556
# England 156 36
#  England      1368
# Germany       919
# Spain         671
# France        614
# Argentina     574
# Italy         469
# Colombia      445
# Japan         425
# Brazil        423
# Name: Nationality, dtype: int64
# England      0.106071
# Germany      0.071257
# Spain        0.052028
# France       0.047608
# Argentina    0.044506
#                ...
# Bermuda      0.000078
# Palestine    0.000078
# Mauritius    0.000078
# Lebanon      0.000078
# Grenada      0.000078
# Name: Nationality, Length: 156, dtype: float64

# %%
import pandas as pd
data = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
#разбиваем на 4 равных кучки по wage
s = data['Wage'].value_counts(bins=4)
display(s)
data.loc[(data.Wage > s.index[3].left)&((data.Wage <= s.index[3].right)) ]
# Out:
# (435.999, 142000.0]     12818
# (142000.0, 283000.0]       61
# (283000.0, 424000.0]       16
# (424000.0, 565000.0]        2
# Name: Wage, dtype: int64
#    Unnamed: 0       Name  Age Nationality          Club      Value    Wage  \
# 0           0   L. Messi   31   Argentina  FC Barcelona  110500000  565000
# 7           7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000
#
#   Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0       RF        84         95  ...         75         96       33
# 7       RS        77         93  ...         85         85       62
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
# 7              45             38        27          25         31
#
#    GKPositioning  GKReflexes
# 0             14           8
# 7             33          37
#
# [2 rows x 42 columns]

# %%
import pandas as pd
data = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
s = data.Nationality.value_counts()
print(s.index, len(s.index))
#unique находит уникальные
#nunique количество уник
q = data.Nationality.unique()
w = data.Nationality.nunique()
print(q, '\n', w)
#преобразует в датафрейм результат валуекаунтса
s_df = s.reset_index()
display(s_df)
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Italy',
#        'Colombia', 'Japan', 'Brazil', 'China PR',
#        ...
#        'Andorra', 'Philippines', 'Botswana', 'Ethiopia', 'Indonesia',
#        'Bermuda', 'Palestine', 'Mauritius', 'Lebanon', 'Grenada'],
#       dtype='object', length=156) 156
# ['Argentina' 'Portugal' 'Brazil' 'Spain' 'Belgium' 'Croatia' 'Uruguay'
#  'Slovenia' 'Poland' 'Germany' 'France' 'England' 'Italy' 'Egypt'
#  'Colombia' 'Denmark' 'Gabon' 'Wales' 'Senegal' 'Costa Rica' 'Slovakia'
#  'Netherlands' 'Bosnia Herzegovina' 'Morocco' 'Serbia' 'Algeria' 'Austria'
#  'Greece' 'Chile' 'Sweden' 'Korea Republic' 'Finland' 'Guinea'
#  'Montenegro' 'Switzerland' 'Norway' 'DR Congo' 'Ukraine' 'Mexico'
#  'Czech Republic' 'Ivory Coast' 'Albania' 'Turkey' 'Ghana' 'Ecuador'
#  'Mali' 'Nigeria' 'Dominican Republic' 'Japan' 'Cameroon'
#  'Republic of Ireland' 'Romania' 'United States' 'Russia' 'Hungary'
# ...

# %%
import pandas as pd
data = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
s = data.groupby(['Club']).mean()
display(s.head(3))
print(s.loc['Ajax'].Wage)

s = data.groupby(['Club']).Wage.sum()
display(s.head(3))

s = data.groupby(['Club']).Wage.sum().sort_values(ascending=False)
print(s.head(3))
# Out:
#                         Unnamed: 0        Age          Value         Wage  \
# Club
#  SSV Jahn Regensburg   5380.166667  25.375000  633125.000000  3750.000000
# 1. FC Heidenheim 1846  5891.700000  23.650000  914500.000000  3800.000000
# 1. FC Kaiserslautern   7276.130435  23.652174  486739.130435  1434.782609
#
#                         Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Club
#  SSV Jahn Regensburg   46.000000  39.333333        53.458333     56.750000
# 1. FC Heidenheim 1846  48.050000  43.000000        47.750000     56.800000
# 1. FC Kaiserslautern   48.086957  39.913043        49.260870     55.304348
#
#                          Volleys  Dribbling  ...  Penalties  Composure  \
# Club                                         ...
#  SSV Jahn Regensburg   39.333333  49.833333  ...  43.416667  55.500000
# 1. FC Heidenheim 1846  42.300000  52.000000  ...  46.150000  54.650000
# 1. FC Kaiserslautern   39.086957  49.173913  ...  44.782609  51.043478
#
# ...

# %%
import pandas as pd
data = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
print(len(data.Club.value_counts()))
print(data.Club.value_counts().index[0])
best = football.FKAccuracy.max()
count = len(football[football.FKAccuracy==best])
print(best, count)
# Out:
# 650
# V-Varen Nagasaki
# 94 1

# %%
import pandas as pd
football = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
s = football.Wage.value_counts(bins=4)
player = football[(football.Nationality == 'Spain')].Wage.value_counts(normalize='True',bins=4).sort_index().iloc[0]*100
player = round(player)
position = football.groupby(['Position']).Wage.sum()
position = position[position>2000000]
Chelsea = football[football.Club == 'Chelsea'].groupby(['Club']).Wage.sum()[0]
print(player, position, Chelsea)
# Out:
# 97 Position
# CAM     5500000
# CB      7476000
# CDM     4921000
# CM      6194000
# GK      8784000
# LB      6096000
# LCB     3989000
# LCM     3145000
# LM      5440000
# LW      2945000
# RB      5034000
# RCB     4711000
# RCM     3241000
# RM      5098000
# RW      3276000
# ST     11873000
# Name: Wage, dtype: int64 2035000

# %%
import pandas as pd
df = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
'''df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])] сортировка по столбцам
В параметр values мы передаем колонку, по которой будем рассчитывать сумму агрегирующей функцией.
В параметр index передадим колонку, данные которой будут строками сводной таблицы.
В параметр columns передаем колонку, значения которой будут в столбцах.
В параметр aggfunc передаем агрегирующую функцию. 
Помнишь, мы проходили их, когда рассматривали функцию groupby? Все эти функции можно применять для сводных таблиц.
fill_value заменияет все NaN на заданное значение

'''
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
      index=['Nationality'],
      columns=['Club'],
      aggfunc='sum',
        fill_value=0)
display(pivot)
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')
df2.loc['Manchester City']['GK']
df3 = df.pivot_table(columns = 'Nationality', index = 'Club', values = "Wage", aggfunc = 'sum', fill_value = 0 )
df3.loc['AS Monaco']['Russia']
# Out:
#                            Wage
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                565000   205000            206000           0
# Belgium                  110000        0            230000      240000
# Bosnia Herzegovina            0   180000                 0           0
# Brazil                   465000   335000             91000      570000
# Chile                    205000        0            215000           0
# Costa Rica                    0        0                 0      195000
# Croatia                  260000   160000                 0      420000
# Dominican Republic            0        0                 0      140000
# Ecuador                       0        0            120000           0
# England                       0        0            478000           0
# France                   495000   145000            375000      459000
# Germany                  240000   160000                 0      355000
# ...

# %%
import pandas as pd
df = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'SprintSpeed', aggfunc = 'mean',margins=True, fill_value = 0)
display(df2)
df2.ST.sort_values(ascending=False)
# Out:
# Position                     CAM         CB        CDM         CF         CM  \
# Club
#  SSV Jahn Regensburg    0.000000  46.600000  82.000000   0.000000  61.000000
# 1. FC Heidenheim 1846  68.000000  61.333333   0.000000   0.000000  68.000000
# 1. FC Kaiserslautern    0.000000  59.000000  65.666667   0.000000   0.000000
# 1. FC Köln              0.000000  60.000000  32.000000   0.000000  68.500000
# 1. FC Magdeburg         0.000000  60.000000   0.000000  64.000000   0.000000
# ...                          ...        ...        ...        ...        ...
# Çaykur Rizespor        74.000000  58.000000  62.800000   0.000000   0.000000
# Örebro SK               0.000000  60.750000   0.000000   0.000000  63.000000
# Östersunds FK          67.000000  76.000000   0.000000  77.000000  56.333333
# Śląsk Wrocław           0.000000  62.000000  66.666667   0.000000  72.000000
# All                    68.236967  57.734854  60.813314  69.803922  64.299906
#
# ...

# %%
import pandas as pd
data = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
#7 data[data.Wage == data.Wage.max()].Position
#8 print(round(data[data.Aggression == data.Aggression.max()].ShotPower.mean()/data[data.Aggression == data.Aggression.min()].ShotPower.mean(),2))
result = len(data['Position'].value_counts())
print(result)
'''10'''
#s = data.groupby(['Club']).Nationality.nunique()
#print(s)
#print(s['Manchester United'])
'''11'''
#s = data.groupby(['Club']).Wage.agg(['mean', 'median'])
#display(s)
#for i in range(650):
#    if s.index[i][1] == s.index[i][2]:
#        print(i)
'''12'''
#data[(data.Nationality == 'Argentina')&
#    (data.Age == 20)].Wage.max()
'''13'''
#df = data.pivot_table(columns='Club', index='Position', values='Name', aggfunc='count', fill_value=0)
#display(df)
#print(round(df.loc['GK'].sum()/650,3))
'''14'''
s = data.pivot_table(columns='Club', index='Position', values='Name', aggfunc='count', fill_value=0)
display(s)
s.loc['CM'].value_counts()
# Out:
# 27
# Club       SSV Jahn Regensburg  1. FC Heidenheim 1846  1. FC Kaiserslautern  \
# Position
# CAM                          0                      1                     0
# CB                           5                      3                     3
# CDM                          1                      0                     3
# CF                           0                      0                     0
# CM                           2                      1                     0
# GK                           3                      2                     3
# LAM                          0                      0                     0
# LB                           2                      2                     2
# LCB                          0                      1                     1
# LCM                          0                      0                     0
# LDM                          1                      0                     0
# ...

# %%
import pandas as pd
ratings = pd.read_csv('https://ai-academy.ru/upload/files/ratings.csv')
display(ratings.head())
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'],unit='s') 
ratings.tail()
movies = pd.read_csv('https://ai-academy.ru/upload/files/movies.csv')
movies.head()
joined = ratings.merge(movies, on='movieId', how='left')
display(joined.head())
'''Для объединения по нескольким столбцам используйте on = ['col1', 'col2'].'''
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#    userId  movieId  rating           timestamp                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# ...

# %%
import pandas as pd
ratings = pd.read_csv('https://ai-academy.ru/upload/files/ratings.csv')
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'],unit='s') 
movies = pd.read_csv('https://ai-academy.ru/upload/files/movies.csv')
display(ratings)
ratings.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
display(ratings)
# Out:
#         userId  movieId  rating           timestamp
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15
#
# [100836 rows x 4 columns]

# %%
import pandas as pd
ratings = pd.read_csv('https://ai-academy.ru/upload/files/ratings.csv')
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'],unit='s') 
movies = pd.read_csv('https://ai-academy.ru/upload/files/movies.csv')
joined = movies.merge(ratings, on='movieId', how='left')
joined = joined.query('rating>4 & genres in ["Action"]')
joined.drop_duplicates(subset='movieId', keep='first', inplace=True)
display(joined)
# Out:
#        movieId                                              title  genres  \
# 602          9                                Sudden Death (1995)  Action
# 5641       204               Under Siege 2: Dark Territory (1995)  Action
# 17707      667  Bloodsport 2 (a.k.a. Bloodsport II: The Next K...  Action
# 32145     1497                                 Double Team (1997)  Action
# 40978     2196                                   Knock Off (1998)  Action
# 53280     3283                        Minnie and Moskowitz (1971)  Action
# 54343     3444                                  Bloodsport (1988)  Action
# 60541     4200                               Double Impact (1991)  Action
# 62086     4387                          Kiss of the Dragon (2001)  Action
# 62214     4441                               Game of Death (1978)  Action
# 65897     5155                          Big Bird Cage, The (1972)  Action
# 75517     7899  Master of the Flying Guillotine (Du bi quan wa...  Action
# ...

# %%
import pandas as pd
'''str.match ("abc") — ищет строки, которые начинаются c abc;
str.contains ("abc") — ищет строки, в которых есть abc.'''
# Out:
# 'str.match ("abc") — ищет строки, которые начинаются c abc;\nstr.contains ("abc") — ищет строки, в которых есть abc.'

# %%
import pandas as pd
ratings = pd.read_csv('https://ai-academy.ru/upload/files/ratings.csv', na_values=0)
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'],unit='s') 
movies = pd.read_csv('https://ai-academy.ru/upload/files/movies.csv', na_values=0)
joined = movies.merge(ratings, on='movieId', how='left')
display(joined.genres.value_counts())
joined = joined[(joined.genres.str.contains ("Fantasy"))&
               (joined.rating>4)&
               (joined.title.str.contains ("2017"))]

joined.drop_duplicates(subset='movieId', keep='first', inplace=True)
display(joined)
# Out:
# Comedy                                             7197
# Drama                                              6294
# Comedy|Romance                                     3968
# Comedy|Drama|Romance                               3001
# Comedy|Drama                                       2851
#                                                    ...
# Comedy|Drama|Fantasy|Mystery|Romance                  1
# Comedy|Crime|Drama|Sci-Fi|Thriller                    1
# Comedy|Crime|Drama|Horror                             1
# Comedy|Romance|Western                                1
# Action|Adventure|Comedy|Fantasy|Sci-Fi|Thriller       1
# Name: genres, Length: 951, dtype: int64
#         movieId                                  title  \
# 98464    122926      Untitled Spider-Man Reboot (2017)
# 99457    143355                    Wonder Woman (2017)
# 100305   168218  Kizumonogatari III: Cold Blood (2017)
# 100691   179819        Star Wars: The Last Jedi (2017)
#
# ...

# %%
import pandas as pd

football = pd.read_csv('https://ai-academy.ru/upload/files/football.csv')
s = football.pivot_table(columns='Position', index='Club', values='Name', aggfunc='count')
#display(s.head())
#display(s.isna().head())
#display(s.dropna()) #удаляет пропуски
#display(s.loc['1. FC Magdeburg'].fillna(0))

# %%
import pandas as pd
ratings = pd.read_csv('https://ai-academy.ru/upload/files/ratings.csv')
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'],unit='s') 
movies = pd.read_csv('https://ai-academy.ru/upload/files/movies.csv')
ratings.isna().rating.unique()
# Out:
# array([False])

# %%
import pandas as pd
ratings = pd.read_csv('http://ai-academy.ru/upload/csv/ratings_mini.csv')
movies = pd.read_csv('http://ai-academy.ru/upload/csv/movies_mini.csv')
joined = movies.merge(ratings, on='movieId', how='left')
man_movie = joined[joined.title.str.contains("man")].title.iloc[0].split(' ')[0]
best = len(joined[(joined.rating>4)])
display(best, man_movie)
# Out:
# 13
# 'Jumanji'

# %%
import pandas as pd
person_dict = { 
    'person_id': [417283, 849734, 132223, 573943, 19475, 3294095],  
    'person_name': ['Keanu Reeves', 'Jim Carrey', 'Johnny Depp', 'Keira Knightley', 'Natalie Portman', 'Marion Cotillard']
}
travel_log = { 
    'travel_id': [101, 102, 105, 121, 145, 161, 178], 
    'person_id': [573943, 132223, 849734, 417283, 382043, 3294095, 417283], 
    'country': ['Russia', 'Australia', 'Turkey', 'Japan', 'China', 'USA', 'Mexico'],
    'price': [5900, 15330, 10200, 12990, 9890, 13500, 7400], 
    'real_cost': [3500, 10280, 7600, 9850, 4340, 11200, 3300]
}

person_dict = pd.DataFrame(person_dict)
travel_log = pd.DataFrame(travel_log)
display(person_dict)
display(travel_log)
'''
join = travel_log.merge(person_dict, on ='person_id', how='outer')
id = (join.loc[len(join)-1][1])'''

merge = travel_log.merge(person_dict, on='person_id', how='inner')
display(merge)
print(len(merge))
# Out:
#    person_id       person_name
# 0     417283      Keanu Reeves
# 1     849734        Jim Carrey
# 2     132223       Johnny Depp
# 3     573943   Keira Knightley
# 4      19475   Natalie Portman
# 5    3294095  Marion Cotillard
#    travel_id  person_id    country  price  real_cost
# 0        101     573943     Russia   5900       3500
# 1        102     132223  Australia  15330      10280
# 2        105     849734     Turkey  10200       7600
# 3        121     417283      Japan  12990       9850
# 4        145     382043      China   9890       4340
# 5        161    3294095        USA  13500      11200
# 6        178     417283     Mexico   7400       3300
#    travel_id  person_id    country  price  real_cost       person_name
# 0        101     573943     Russia   5900       3500   Keira Knightley
# 1        102     132223  Australia  15330      10280       Johnny Depp
# 2        105     849734     Turkey  10200       7600        Jim Carrey
# ...

# %%
import pandas as pd
data = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')
data.info()
data.total_bill.plot(kind = 'hist', grid = True, title = 'Название диаграммы')
data.day.value_counts().plot(kind='bar',
                            grid=True,
                            colormap='coolwarm',
                            title='посетители по дням')
data[['total_bill', 'tip']].plot(kind='hist',
                            grid=True,
                            subplots=True,
                            title=['общая сумма', "сумма чаевых"],
                            legend=False)
data.pivot_table(index = 'sex', columns = 'vegan', values = 'tip').plot(kind = 'bar', grid= True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   vegan       244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# <AxesSubplot:xlabel='sex'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')
#df.groupby(by = ['sex', 'vegan'])['tip'].mean().plot(kind = 'bar', grid= True)
#df.groupby('vegan')['tip'].count().plot(kind = 'bar')
#df['vegan'].value_counts().plot(kind = 'bar')
# %matplotlib inline
fig = plt.figure()
axes = fig.add_axes([0, 0, 1, 1])
axes.hist(df['total_bill'], bins = 20, color = 'green')
axes.set_title('Общая сумма счета')
axes.set_ylabel('Количество заказов')
axes.set_xlabel('Сумма заказа, USD')
# Out:
# Text(0.5, 0, 'Сумма заказа, USD')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')
fig = plt.figure()
axes = fig.add_axes([0, 0, 1, 1])
axes.scatter(x = df['total_bill'], y = df['tip'], marker = 'o')
axes.set_title('Общая сумма счёта Vs Cумма чаевых')
axes.set_xlabel('Сумма чека')
axes.set_ylabel('Размер чаевых')
# Out:
# Text(0, 0.5, 'Размер чаевых')

# %%
import pandas as pd
import matplotlib.pyplot as plt
tips = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])

axes.set_ylim(0,25)
axes.bar(x=tips.day, height = tips.total_bill.mean(),
        width= 0.4, align='edge', label="Средняя сумма чека")
axes.bar(x=tips.day, height = tips.tip.mean(),
        width=-0.4, align='edge', label="Средняя сумма чаевых")
axes.set_title("Средняя сумма счета вс сумма чаевых по дням недели")
axes.set_xlabel("week's day")
axes.set_ylabel("Sum")
axes.legend(loc = 1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')
'''plt.subplots(N row,N columns, figsize=(len, height))'''
fig, axes = plt.subplots(2,2, figsize=(20, 12))

axes[0][0].hist(df.total_bill)
axes[0][0].set_title('Общая сумма счета')

axes[1][0].hist(df.tip)
axes[1][0].set_title("Сумма чаевых")

axes[0][1].scatter(x=df.total_bill, y=df.tip, marker = 'o')
axes[0][1].set_title("Общая сумма счета vs Сумма чаевых")
# Out:
# Text(0.5, 1.0, 'Общая сумма счета vs Сумма чаевых')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')

sns.set()
sns.displot(df.total_bill)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')
sns.jointplot(x=df.total_bill, y=df.tip, kind='resid')
sns.jointplot(x=df.total_bill, y=df.tip, kind='reg')
sns.jointplot(x=df.total_bill, y=df.tip, kind='kde')
sns.jointplot(x=df.total_bill, y=df.tip, kind='hex')
sns.jointplot(x=df.total_bill, y=df.tip, kind='scatter')
sns.jointplot(x=df.total_bill, y=df.tip, kind='hist')
# Out:
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')

sns.pairplot(df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')
'''countplot среднее по группе'''
#sns.countplot(x='day', data=df)
'''barplot среднее по группе'''
#sns.barplot(x='sex', y='total_bill', data=df)
sns.pairplot(df, hue = 'vegan')

# %%
import pandas as pd
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# %matplotlib inline
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')
init_notebook_mode(connected = True)
cf.go_offline()

df.groupby(by = 'day')['total_bill'] .agg(['min','max']).plot()
df[['tip','total_bill']].iplot()
df.pivot_table(index = 'day', columns = 'sex', values = 'total_bill', aggfunc = 'mean').plot(kind = 'bar')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
import numpy as np
arr1 = np.array([[1,2,3,4],
               [2,3,5,7]])
arr2 = np.array([1,5,6], dtype=float)
print(arr1,arr2)
print(arr2.dtype)
print(np.shape(arr1))
my_array = np.array([[1,2,3,4], [10,11,12,13], [45,46,47,48]])
print(my_array[1][2])
print(my_array[0,2])
my_secret = [x for x in range(1, 301, 7) if x%10 == 7 or x%10 == 1]
np.array([my_secret, [x/2 for x in my_secret], [x-100 for x in my_secret]])
# Out:
# [[1 2 3 4]
#  [2 3 5 7]] [1. 5. 6.]
# float64
# (2, 4)
# 12
# 3
# array([[  1. ,  57. ,  71. , 127. , 141. , 197. , 211. , 267. , 281. ],
#        [  0.5,  28.5,  35.5,  63.5,  70.5,  98.5, 105.5, 133.5, 140.5],
#        [-99. , -43. , -29. ,  27. ,  41. ,  97. , 111. , 167. , 181. ]])

# %%
import numpy as np
A = np.array([[1,-5,3],[2,2,1],[0,3,1],[2,4,12]])
print(A.shape)
print('a_23 = ', A[1,2],'; a_32 = ', A[2,1])
B = np.matrix("1,-5;2,2;0,3")
C = np.matrix("3,-1;2,6;4,0")
print(C+B)
print(C*B.T)
A_1 = np.matrix("1,-5;2,2;0,3")
A_2 = np.matrix("3,1,0;-1,0,2")
print(np.dot(A_1,A_2))
print(np.dot(A_2,A_1))
print(np.matrix(['8,13,18,4; 25,3,18,28; 14,15,18,24; 1,2,3,4']))
# Out:
# (4, 3)
# a_23 =  1 ; a_32 =  3
# [[ 4 -6]
#  [ 4  8]
#  [ 4  3]]
# [[  8   4  -3]
#  [-28  16  18]
#  [  4   8   0]]
# [[  8   1 -10]
#  [  4   2   4]
#  [ -3   0   6]]
# [[  5 -13]
#  [ -1  11]]
# [['8,13,18,4; 25,3,18,28; 14,15,18,24; 1,2,3,4']]

# %%
import numpy as np
rating = np.array([[1,280,892,621],
                    [2,254,742,763],
                    [3,352,820,757],
                    [4,189,730,614],
                    [5,209,758,608],
                    [6,312,652,545],
                    [7,199,680,553],
                    [8,224,592,485],
                    [9,293,603,466],
                    [10,187,507,423]])
print(np.mean(rating[:,-1]))
print(np.median(rating[:,-1]))
print(np.corrcoef(rating[:,-1], rating[:,1]))
print(np.std(rating[:,-1]))

cor12 = np.corrcoef(rating[:,1],rating[:,2])[0][1]
cor13 = np.corrcoef(rating[:,3],rating[:,1])[0][1]
cor23 = np.corrcoef(rating[:,2],rating[:,3])[0][1]
c_min = round(np.min([cor12,cor13,cor23]),2)
print(c_min)
# Out:
# 583.5
# 580.5
# [[1.         0.39839893]
#  [0.39839893 1.        ]]
# 108.13903088154619
# 0.38

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')

correlation = df.corr()
display(sns.heatmap(correlation , annot = True, cmap = 'coolwarm'))

rating = np.array([[1,280,892,621],
                    [2,254,742,763],
                    [3,352,820,757],
                    [4,189,730,614],
                    [5,209,758,608],
                    [6,312,652,545],
                    [7,199,680,553],
                    [8,224,592,485],
                    [9,293,603,466],
                    [10,187,507,423]])
rat = (pd.DataFrame(rating)).corr()
display(sns.heatmap(rat , annot = True, cmap = 'coolwarm'))
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('https://ai-academy.ru/upload/csv/Restaurant.csv')

#display(sns.boxplot(x='day', y='tip', data=df))
#display(sns.boxplot(x='day', y='tip', data=df,hue='vegan'))
display(sns.boxplot(x='day', y='tip', data=df,hue='sex'))
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import pandas as pd
import seaborn as sns
Video_blog_DF = pd.DataFrame({'Duration': [275, 383, 628, 712], 
                                'Views': [305, 629, 843, 726], 
                                'Likes':[23, 78, 65, 90],
                                'Dislikes':[5, 12, 26, 10], 
                                'Comments':[2, 6, 15, 28]})
Video_blog_DF.iloc[2].values
Video_blog_DF.iloc[3]. loc['Likes']
# Out:
# 90

# %%
import numpy as np
bigdata = np.array([i**2 for i in range(100,1000)])
md = np.median(bigdata)
so = round(np.std(bigdata),0)
cor = round(np.corrcoef(bigdata[bigdata%2==1],bigdata[bigdata%2==0])[0][1],2)
print(md, so, cor)
# Out:
# 301950.5 291841.0 1.0
